# %% [markdown]
# ### _Submitted By : Sneha Rane_

# %% [markdown]
# # Task 1 : Prediction Using Supervised ML
#
# ## What is Supervised Learning ?
#
# In Supervised learning, we train the machine using data which is well "labeled". Some data is already tagged with the correct answer. It can be compared to learning which takes place in the presence of a supervisor or a teacher.
#
# A supervised learning algorithm learns from labeled training data, helps you to predict outcomes for unforeseen data.
#
# ![supervised-machine-learning.png](https://static.javatpoint.com/tutorial/machine-learning/images/supervised-machine-learning.png)
#
# ## **Linear Regression with Python Scikit Learn**
#
# Linear regression is one of the easiest and most popular Machine Learning algorithms. It is a statistical method that is used for predictive analysis. Linear regression makes predictions for continuous/real or numeric variables such as sales, salary, age, product price, etc.
#
# Linear regression algorithm shows a linear relationship between a dependent (y) and one or more independent (y) variables, hence called as linear regression. Since linear regression shows the linear relationship, which means it finds how the value of the dependent variable is changing according to the value of the independent variable.
# In this section we will see how the Python Scikit-Learn library for machine learning can be used to implement regression functions.
#
# ![linear-regression.png](https://static.javatpoint.com/tutorial/machine-learning/images/linear-regression-in-machine-learning.png)
#
# ### **Simple Linear Regression**
# In this regression task we will predict the percentage of marks that a student is expected to score based upon the number of hours they studied. This is a simple linear regression task as it involves just two variables.

# %%
# Importing all libraries required in this notebook
import pandas as pd
import numpy as np  
from matplotlib import pyplot as plt  
# %matplotlib inline

# %%
# Reading data from remote link

df = pd.read_csv('student_scores.csv')
print("Data imported successfully")

df.head(10)
# Out:
# Data imported successfully
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %% [markdown]
# Let's plot our data points on 2-D graph to find any relationship between the data.

# %%
# Plotting the data to visualize the distribution of scores

fig = plt.figure()

df.plot(x='Hours', y='Scores', style='o',figsize=(10,5))  
plt.title('Distribution of Scores with respect to Hours\n', fontsize=20)  
plt.xlabel('Hours Studied', fontsize=14)  
plt.ylabel('Score in %', fontsize=14)  
plt.show()

# %%
# Line plot
fig = plt.figure()

df.plot(kind = 'line',figsize=(10,8))
plt.title('Distribution of Scores with respect to Hours\n', fontsize=20)  
plt.xlabel('Hours Studied', fontsize=14)  
plt.ylabel('Score in %', fontsize=14)  
plt.show()

# %% [markdown]
# **From the graph above, we can clearly see that there is a positive linear relation between the number of hours studied and percentage of score.**

# %% [markdown]
# ### **Preparing the data**
#
# The next step is to divide the data into "attributes" (inputs) and "labels" (outputs).

# %%
X = df.iloc[:, :-1].values  # Hours
y = df.iloc[:, 1].values    # score

# %% [markdown]
# Now that we have our attributes and labels, the next step is to <b>split this data into training and test sets</b> by Scikit-Learn's built-in train_test_split() method :
#
# ![split the dataset](https://www.python-course.eu/figures/splitting_data_learn_test.png)

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                            test_size=0.2, random_state=0)

# %% [markdown]
# ### **Training the Algorithm**

# %%
from sklearn.linear_model import LinearRegression  
lr = LinearRegression()  
lr.fit(X_train, y_train) 

print("Training completed.")
# Out:
# Training completed.

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [9.91065648]
# 2.018160041434669

# %%
# Plotting the regression line
line = lr.coef_*X+lr.intercept_

fig = plt.figure()

# Plotting for the test data
plt.scatter(X, y,color='crimson')
plt.plot(X, line, color='gold');
plt.title('\nDistribution of Scores with respect to Hours\n', fontsize=16)  
plt.xlabel('Hours Studied', fontsize=14)  
plt.ylabel('Score in %', fontsize=14)  
plt.show()

# %% [markdown]
# ### Making Predictions

# %%
print(X_test) # Testing data - In Hours
y_pred = lr.predict(X_test) # Predicting the scores
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %% [markdown]
# ### Comparing Actual vs Predicted

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
df
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %% [markdown]
# ### You can also test with your own data

# %%
# You can also test with your own data
hours = 9.25
own_pred = lr.predict([[hours]])
print("Number of Hours to study = {}".format(hours))
print("Predicted Score in % = {}".format(own_pred[0]))
# Out:
# Number of Hours to study = 9.25
# Predicted Score in % = 93.69173248737538

# %% [markdown]
# ### **Evaluating the model**
#
# The final step is to evaluate the performance of algorithm. This step is particularly important to compare how well different algorithms perform on a particular dataset.

# %%
from sklearn import metrics

# %% [markdown]
# #### 1. Mean Absolute Error (MAE)
# - It is mean of absolute value of error
# - we can say, its just an average error.

# %%
print('Mean Absolute Error = ', 
      metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error =  4.18385989900298

# %% [markdown]
# #### 2. Mean Squared Error (MSE)
# - Mean of squared error
# - Focuses more on large errors
# - Occurs due to squared term exponentially increasing larger errors in comparison to smaller ones.

# %%
print('Mean Squared Error = ', metrics.mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared Error =  21.598769307217413

# %% [markdown]
# #### 3. Root Mean Squared Error (RMSE)
# - Square root of MSE
# - Popular evaluation metric because RMSE is interpretable in same units as response vector or y units
# - Easy to relate its information

# %%
print('Root Mean Squared Error = ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Root Mean Squared Error =  4.647447612100368

# %% [markdown]
# ### Calculating R Square value
#
# R-squared is a goodness-of-fit measure for linear regression models. This statistic indicates the percentage of the variance in the dependent variable that the independent variables explain collectively. R-squared measures the strength of the relationship between your model and the dependent variable on a convenient 0 – 100% scale.

# %%
lr.score(X,y)
# Out:
# 0.9526947647057274
